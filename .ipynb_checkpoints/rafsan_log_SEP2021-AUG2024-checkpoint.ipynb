# %% [markdown]
# # This log is the continuation of my 2nd-3rd year of PhD (SEP2021-AUG2024)

# %% [markdown]
# ## Overview
#
# ### Active Projects
#
# 01. NLP on biomedical text
# 02. Swedish NLP on clinical data (future)
# 03. Mariam and Malou cell profiler and unet works
# 04. Ancient DNA (No news yet)
# 05. Personal short project (need to find ideas)
#
# ### General Targets
#
# 01. NLP technical knowledge (papers, models, seminars)
#     a. BERT and BIOBERT
#     b. GPT3
#     c. SparkNLP
#     d. NER
#     e. RE
#     f. Neural coref
#     g. Topic modelling
#     h. Word2vec and basics
#     i. NLP stanford
#
# 02. ML/DL technical knowledge (papers, models, seminars)
#     a. TF
#     b. Pytorch
#     c. Mask-RCNN
#     d. Yolo
#     e. coco
#     f. efficientnet
#     g. DL michigan
#     h. Image segmentation pipelines
#
# 03. Finish all PhD courses including "knowledge in collaboration" in November
# 04. Submit statII task
# 05. Attend seminar from:
#     a. Swedish Bioinformatics
#     b. EDEON
#     c. Mobile heights Sweden
#     d. Peltarion
#     e. From copenhagen (Astrazeneca + Novonordisk + Jesper Johnsson + NLP)
#     f. LTH career fare from ARKAD
#
# 06. Hub AI leadership duties (speakers, events, talks, networking, management)
# 07. Peer Learning Group events (Creation and management). Add to teaching duties.
# 08. Grant writing (travel grant, short project)
# 09. 1 new paper/2 weeks
# 10.
#
#
# ### Tools
#
# 01. SQL
# 02. Docker/singularity
# 03. AWS/Azure
# 04. Julia (trial)
# 05. Agile
# 06. C++ (if possible)
#
# _______________________________________________
#
# ### Deadline by OCT 2021
# 01. Create Docria collections for all texts in concern (json/pdf) [Done]
# 02. Run models [Done for Biobert and biobert large]
# 03. Find the best models, evaluate and test.
# 04. Find short project idea and do some trials (sparkNLP?)
# 05. ?
#
# ### Deadline by NOV 2021
# 01. Finalize short project and rough draft.
# 02. ?
#
# ### Deadline by DEC 2021
# 01. Publishing 1 NLP paper
# 02. Publish 1 paper based on the current results (NLP or otherwise)
# 03. Draft 1 small project paper

# %% [markdown]
# # Project plan 2023
#
# ### May 29- June 2
# Pubmed: download and process - write base scripts. Create a pubmed_downloader repo
#
# ### June 5-9
# Pubmed: download, process, split and deployment of chemical HUNER model
#
# ### June 12-16
# Implementation of RE models done by students (Nils, Jacob and lykke-klara): BioGPT, RoBERTa and SciBERT
#
# ### June 19-23
# Model adjustment, model selection, training and improvement
#
# ### June 26-30
# Deployment of 11 RE Models: chemical, disease, gene and species (+cell and env)
#
# ### July 3-7
# Deployment of RE Models - writing paper
#
# ### July 10-14
# RE models result interpretation - writing paper
#
# ### July 17-21 (conf)
# RE models result interpretation - writing paper
#
# ### July 24-28
# RE finalize draft + interpretations
#
# ### Jul 31- Aug 4
# Re finalize draft + interpretations

# %% [markdown]
# # 8th September 2021
# ---
# ### Project
# NLP Pipeline
#
# ### Aim
# Convert docria collection to readable chunks
#
# ### Description
# 1. Get docria collection of full text
# 2. Create a script to convert to sentence level.
# 3. ?
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
# # 10th September 2021
# ---
# ### Project
# NLP Pipeline
#
# ### Aim
# Convert docria collection to readable chunks
#
# ### Description
# 1. Get docria collection of full text
# 2. Create a script to convert to sentence level.
# 3. ?
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
# # 30th September 2021
# ---
# ### Project
# NLP Pipeline
#
# ### Aim
# Minutes of the meeting with Sonja
#
# ### Description
# #### Accomplished tasks:
# 1. Docria full conversion of CORD 8th August,2021 text [should make a proper github repo for it]
# 2. Ran 10 models biobert/biobert large
# 3. Loaded pytorch models and got weird results
#
# #### Discussed future tasks
# 1. What kind of error does the large models make? Make a script to compare individual sentences.
# 2. Try to see which entities are missed and if it is the same word/words on multiple occasions.
# 3. Something like
# | sentence | correct entity | missed entity |
# | ----- | ------- | ----- |
# | ----- | ------- | ----- |
#
# #### Poster and grants
# 1. SBW deadline for poster and 3 minute video: 19th October
# 2. Find grants for salary (if available)
# 3. Mediatryck poster expenses: 400-600SEK according to website
# 4. Find out the documents that are needed (ex: recommendation letter and contents)
#
# #### Poster content
# 1. Background and intro
# 2. Visuals: doc-collections -> NER -> CFC?
# 3. Most important results
# 4. Loaders and matching text in docria: text chopped up
# 5. use gimp, pp, slideshare, biobert/hunflair poster
#
# #### Paper content
# 1. Part I: Evaluation on HunFlair text
# 2. Part II: Evaluation on CRAFT or another corpora
# 3. Part III: Run on CORD - mayber paper II
# EG: Looking at CORD19, these are the most frequent cell lines
# 4.
#
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
# # 19th October 2021
# ---
# ### Project
# NLP Pipeline
#
# ### Aim
# Instructions
#
# ### Description
# 1. Find total number of entities discovered by each model
# 2. list of entities sorted by mention frequency for each class, across the entire dataset.
# 3. Number of entities per document
#
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
# # 4th November 2021
# ---
# ### Project
# NLP Pipeline
#
# ### Aim
# Data info
#
# ### Description
# 1. The data for biobert and Hunflair models was obtained from NER100 repo by Adam and Ola, curated by Marcus.
# The data is available on https://github.com/Aitslab/BioNLP/tree/master/Adam_Ola/ner_inputs
#
#
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
# # 11th November 2021
# ---
# ### Project
# NLP Pipeline
#
# ### Aim
# Create NER for names
#
# ### Description
#
# Looked at Regex patterns but did not manage to create a proper spacy phrasematcher NER model for names. Not sure how to approach this task.
#
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
# # 4th February 2022
# ---
# ### Project
# GS paper
#
# ### Aim
# Fix paper
#
# ### Description
#
# 1. Plurals for new file
# 2. Add new terms to dictionary
# 3. Finalize paper
# 4. Check doaj and LU open access
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
# # 28th February 2022
# ---
# ### Project
# GS paper
#
# ### Aim
# Fix paper
#
# ### Description
#
# 1. Plurals for new file
# diseases original: 12906 terms, merged and corrected: 13135 terms  + 7 added terms, 13124 after removing plurals
#
# ["New coronavirus",
# "Novel coronavirus",
# "Chinese virus",
# "China virus",
# "Chinese coronavirus",
# "China coronavirus",
# "kung flu"
# ]
#
# virus original: 218 terms, merged and corrected: 357 terms, 352 after removing plurals
#
# 2. Variants dictionary:
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
# # 8th March 2022
# ---
# ### Project
# GS paper
#
# ### Aim
# Finalize paper
#
# ### Description
#
# 1. Manually fixed XML gold standard annotations
# 2. Created JSON from salma's script
# 3. Created CSV from JSON (dict based)
# 4. Uploaded manuscript_v2 folder to github
# 5. Awaiting approval from Sonja
#
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
# # 21st March 2022
# ---
# ### Project
# GS paper
#
# ### Aim
# Finalize paper
#
# ### Description
#
# Used the following functions to create the virus dictionary:
# 1. dehyphenate and lowercase terms obtained from new literature
# 2. add 2019 variants: 2019 as prefix and suffix plus 2019 new, 2019new, 2019 novel, 2019novel to the terms, given that 2019 or 19 doesn't exist within the term already
# 3. interchange wuhan and hubei terms
# 4. remove sentences with duplicate words as well as sentences with both new and novel terms together
# 5. Merge with original file
#
# Used the following functions to create the disease dictionary:
#
# 1. Load terms from new literature
# 2. Load terms from cv file https://github.com/Aitslab/BioNLP/blob/master/sonja/cv_terms.md
# 3. Load the new processed virus terms.
# 4. Added new terms to (1) disease terms as well as well as the disease terms in (2).
# new_terms = ['new coronavirus','novel coronavirus','chinese virus','china virus','chinese coronavirus','china coronavirus','kung flu']
# 5. Combine the new virus terms with terms from the cv file to make new disease terms. Place virus name, wuhan or hubei at [virus name or Wuhan or Hubei] position and virus name at [virus name] position to create variants. Remove hyphens, lowercase and remove duplicates.
# 6. merge 4 and 5: disease terms and new disease terms from virus
# 7. Interchange corona and coronavirus
# 8. Interchange wuhan and hubei
# 9. Interchange [disease, syndrome, infection, pneumonia and disorder]
# 10. Remove duplicate words or when both new and novel exists in term
# 11. Merge with original file
#
#
#
# ### Results/Conclusions
# 802 virus terms, 89893 disease terms
#
#
# ### Next Steps

# %% [markdown]
# # 22nd-23rd March 2022
# ---
# ### Project
# GS paper
#
# ### Aim
# Finalize paper
#
# ### Description
#
# Added notebook to repo, fixed one comma
# Fixed jupyter notebook
# added reference
# merged scripts, added silver standard
#
# ### Results/Conclusions
#
# Paper ready
#
# ### Next Steps
# NLP Pipeline

# %% [markdown]
# # 22nd-23rd March 2022
# ---
# ### Project
# GS paper
#
# ### Aim
# Finalize paper
#
# ### Description
#
# Added notebook to repo, fixed one comma
# Fixed jupyter notebook
# added reference
# merged scripts, added silver standard
#
# ### Results/Conclusions
#
# Paper ready
#
# ### Next Steps

# %% [markdown]
# # 1st apr 2022
# ---
# ### Project
# NLP pipeline
#
# ### Aim
# Running RE models by lykke/klara
#
# ### Description
#
# #### tasks
# 1. get artificial models from lykke klara
# 2. put into lunarc
# 3. Biobert issue for post processing
# 4. Scibert integration
# 5. lykke klara model should work on pipeline
# 6. Evaluation script should work
# 7. Is evaluation made on the custom label (corpora lykke axlin)
# 8. Add micro f1 to eval script
# 9. Run lykke eval script (important)
#
# #### Trials/comments on running their code
# 1. Running eval standalone doesnt work, need metrics file. Loader has encoding issue, may need to fix it using utf8 encoding
# 2. Running finetune alone requires imblearn module
# 3. model doesn't load
# 4. Issue with charmap (encoding) of the model. Need to explore alternatives
#
# ### Results/Conclusions
#
# Both loading options from notebook and their script failed. Need to figure out a way to load
#
# ### Next Steps

# %% [markdown]
# # 4th apr 2022
# ---
# ### Project
# NLP pipeline
#
# ### Aim
# Re evaluating biobert models
#
# ### Description
#
# #### tasks
# 1. Figure out why some large models have 0 F1 scores
# 2. identify what max_seq_length within the tokenizer represents
# 3. Run cell and gene models (also on training set) to see why they don't work
#
#
# ### Results/Conclusions
#
# 1. The large cell model for example didn't have any precision, recall score. Using the model on gene corpora and train set resulted in same results.
#
# ** One important thing was that the cached files within the corpora had to be removed each time before training. Therefore that may have caused some issues with fine tuning?
#
# 2. Max_seq_length within the tokenizer is set as a large number as default. However the model allows 512 tokens as a limit. Therefore, the tokenizer should also have 512 tokens as input and ignore the rest. The discrepency between the run model (with 192 cutoff) and the loaded, pretrained model (512) is still unclear
#
# 3. Rinning cell model on gene, training set and test sets proved useless. The main issue seems to be with the model as there are no predictions
#
# ### Next Steps

# %% [markdown]
# # 5th apr 2022
# ---
# ### Project
# NLP pipeline
#
# ### Aim
# Re evaluating biobert models
#
# ### Description
#
# #### tasks
# 1. Trying to retrain cell models again (biobert large)(6.5 hours runtime wit v100)
# 2. Trying to run scibert from lykke/klara
#
#
# ### Results/Conclusions
# 1. The cell models with biobert large fails to predict any entities on the eval and test set. Meaning the model is not training,
# 2. The scibert model could not be loaded. Had issues with charmap codec or model load error (or both). I need to go through the script
#
#
# ### Next Steps

# %% [markdown]
# # 6th apr 2022
# ---
# ### Project
# NLP pipeline
#
# ### Aim
# Re evaluating biobert models
#
# ### Description
#
# #### Meeting with Sonja
# 1. Run lykke/klara script and get re.py working
# 2. Add both macro and micro F1 to scbert eval
# 3. Add a table for NER results
# 4.
#
#
# ### Results/Conclusions
# 1. The cell models with biobert large fails to predict any entities on the eval and test set. Meaning the model is not training
# 2. The scibert model could not be loaded. Had issues with charmap codec or model load error (or both). I need to go through the script. I think the issue is not with the model itself but the path they are recommending. I am not sure how their model was trained
#
# ![image.png](attachment:image.png)
#
# ### Next Steps

# %% [markdown]
# # 11th apr 2022
# ---
# ### Project
# ELLIT
#
# ### Aim
# Hosting
#
# ### Description
#
# #### tasks
# 1. Meeting with kristian
# 2. Need to be there for the whole period.
# 3. Organize social activities
#
# Finalizing NLP pipeline:
#
# 1. Need to integrate downloader scripts to
#
# ### Results/Conclusions
#
# ### Next Steps

# %% [markdown]
# # 12th apr 2022
# ---
# ### Project
# NLP pipeline
#
# ### Aim
# Pipeline
#
# ### Description
#
# #### tasks
# 1. Test re script and evaluate results:
#
# The re script written by lykke/klaara seems to have an issue with loading. I have had the following issues:
#
# 1. Model not recognized
# 2. Input file has charmap/utf8 issues
# 3. Metrics files don't get written
#
# Even after several trials on Alvis and jupyter notebooks, the files failed to run. I decided to run with my own script.
#
# Note that the training part ran smoothly for the RE section.
# Solution: rewrite script and add to the pipeline
#
#
# ### Results/Conclusions
#
#
# ### Next Steps

# %% [markdown]
# # 13th apr 2022
# ---
# ### Project
# NLP pipeline
#
# ### Aim
# Pipeline
#
# ### Description
#
# Stitch pipeline together. Add re parts if possible
#
# #### tasks
# 1. Cloned git repo (https://github.com/Aitslab/NER_pipeline/tree/main) and made a branch called rafsan_dev
# 2. Created a data folder to keep data attributes such as pmid_list
# 3. upgraded spacy 3.2.0 to 3.2.4 (log in case error occurs)
# 4. uninstalled cupy 113 and kept 110
# 5. [python -m spacy download en_core_web_sm] command worked and spacy library was loadable
# 6. had to install pubmed parser using the following commands:
#     git clone https://github.com/titipata/pubmed_parser
#     pip install ./pubmed_parser
#
# 7. Added nerinferencesession_biobert_onnx to scripts/metrics.py within the branch AND to biobert_netrics function within the same metrics.py file
# 8.
#
#
#
# ### Results/Conclusions
# 1.
#
# ### Next Steps

# %% [markdown]
# # 19th apr 2022
# ---
# ### Project
# NLP pipeline
#
# ### Aim
# Pipeline fix
#
# ### Description
#
# Stitch pipeline together
#
# #### tasks
# 1. Working on the raf_dev branch of https://github.com/Aitslab/NER_pipeline/tree/main repo
# 2. added cord_uid subset to cord loader file.
# 3. added cord loader file to repo (need to add whole cord with help of docria?)
# 4. check splitter. it works well with spacy. haven't tested nltk part yet.
# 5. splitting NER session into individual model files. So instead of having a long command and nested if statements, we have individual scripts for individual models. short and efficient.
# 6. Started off with spacy phrasematcher part written by sonja. Haven't been able to run it successfully yet
#
#
#
# ### Results/Conclusions
# 1. Working tree until splitter
# 2.
#
# ### Next Steps

# %% [markdown]
# # 20th apr-18th May 2022
# ---
# ### Project
# ELLIT Focus period
#
# ### Aim
# Do a bunch of things
# -hackathon
# -seminar
# -workshop
# -course on dimensionality reduction
#
# ### Description
#
# 1. Presented my NLP pipeline project work
# 2. Hackathon on Annonymization (used gaussian copula SDV) and autophagy (created graph on autophagy + localization)
# 3. Course on dim reduction - PCA, UMAP, tSNE, optimal transport, graph clustering, kernel methods
# 4. Seminar series from scholars
#
#
# ### Results/Conclusions
# ??
# Pretty useful to see where people stand in the field and what is required to work in the industry
#
# ### Next Steps
# go back to work

# %% [markdown]
#  # 24-25th May
# ---
# ### Project
# NLP pipeline
#
# ### Aim
# Get 1000 pubmed articles and run pipeline on them
#
# ### Description
#
# 1. Manually gotten 1000 pubmed articles with keyword MTOR AND TSC1
# 2. Environment crashed, deleted all nicely mate conda envs and anaconda itself due to package clashes. Installed new conda.
# 3. For future reference, reversing on a conda env may be useful for package conflicts.
# 4. Also, try installing mostly with conda on conda envs
# 5. Ran 1000 articles using spacy splitter and biobert ner. Took about a few seconds + 7.42 mins + 8.02 mins overall.
# 6. Need to update the pipeline and add all kinds of models to it.
#
#
#
# ### Results/Conclusions
# Time:
# downloader = few secs
# Splitter with spacy tokenizer: 7.42 min
# BioBERT NER chem (autotokenizer input): 8.04 min
#
#
# ### Next Steps
# 1. Add multithreading/multiprocessing to the NER (check if doable)
# 2. Create a batch maker script and a batch merger script to combine everything
#
# Fix pipeline and make it runable with one click

# %% [markdown]
#  # 30th May
# ---
# ### Project
# NLP pipeline
#
# ### Aim
# Get 1000 pubmed articles and run pipeline on them
#
# ### Description
#
# 1. Added a separate biobert_ner script to the scripts folder. The idea is to have a separate script for loading each model.
# 2. How to set up the pipeline in a way that takes the least amount of effort for model loading?
# 3. Test ner_inference_onnx model so that that part works standalone. Need to figure out some parameters (co-oc, script params e.g.) and output.
# UNFORTUNATELY that could not be done because the model wouldn't load. Need to come back to it
# ![image.png](attachment:image.png)
# 3. Fixing main file so that each script is run smoothly. Doing it from scratch (best approach)
# 4.
#
#
#
# ### Results/Conclusions
# 1. Once main is compatiable and the script runs smoothly, work on adding docria layer to the output. Find a way to streamline the process so that the layers are compatiable.
# 2. Think of multiple batch processing for cord + multiprocessing/multithreading
#
#
# ### Next Steps
# Fix pipeline and make it runable with one click

# %% [markdown]
#  # 31st May
# ---
# ### Project
# NLP pipeline
#
# ### Aim
# Fix pipeline and add output layers
#
# ### Description
#
# 1. NER onnx part will work when loading onnx file as model path (model+vocab) paths separate + onnxruntime 1.4.0 installed. Now it works for the loading parts at least. Note that for biobert the model dir path has to be given and for onnx the model itself. Make sure to provide absolute path
#
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
# Fix pipeline and make it runable with one click

# %% [markdown]
#  # 1st June
# ---
# ### Project
# Meeting with Sonja
#
# ### Aim
# Multiple aspects: halftime + manuscript/Pipeline + conference
#
# ### Description
#
# #### Halftime - Mid September
# 1. Writing help for halftime from academic support center (salma may send an email to them) and booking an appointment.
# 2. Fill up portfolio - check irans and attend one halftime seminar of students
# 3. prepare 1-3 pages of summary of work (1.5 pages) and one half page abstract
# 4. Courses check - stat
# 5. Manuscript prep important for halftime (req)
# 6. Check 12 point req for portfolio.
# 7. Potential reviewers: Lars Juhl Jensen and Dag.
# 8. Check rise for potential nlp reviewers.
# 9. Add career dev, ethics etc to portfolio
#
# #### Manuscript - Important to submit before August
# 1. Prep clean manuscript. Add preprocessing steps.
# 2. Select for each entity type (chem, prot etc.) which 2 models perform the best.
# 3. We want to publish preprint and release models at the same time.
# 4. Check tokenizer according to Nils's analysis. Do I need to run the model again? Check marcus's code on separate tokenizers.
# 5. Prepare a table with huner dataset vs which parts are within corpora evaluated by biobert.
# 6. Have one table for each entity - train, eval and test; precision, recall and F1.
# 7. Check CRAFT corpus and if it can be used to evaluate (benchmark?)
# 8. Feedback on Nil's report.
#
# #### Conference  - June 13-14
# 1. Sonja approved
# 2. Email Noor, ask how traktamente works
# 3. Book ticket through LU intramed
# 4. Get poster done from mediatryck
#
#
#
# ### Results/Conclusions
# 1. Shitload of things to do. Mostly manuscript and finishing the code so pipeline runs smoothly.
#
#
# ### Next Steps
# ...?

# %% [markdown]
#  # 2nd June
# ---
# ### Project
# NLP pipeline
#
# ### Aim
# NER + Fixing biobert output issue
#
# ### Description
#
# 1. Ran ner_inference, checked output and added biobert to the pipeline
# 2. Biobert does have a separate load folder (which I can update) but for now going with the base if..else structure. Refer to the biobert_finetuned script for details
# 2. Grouped entities are deprecated. So used Aggresion_strategy = "max" which takes into account the highest scoring tokens as well as whole words.
#
#
# ### Results/Conclusions
# 1. Shitload of things to do. Mostly manuscript and finishing the code so pipeline runs smoothly.
#
#
# ### Next Steps
# ...?

# %% [markdown]
#  # 3rd June
# ---
# ### Project
# NLP pipeline
#
# ### Aim
# Make sure pipeline outputs are working and then look into trainer to figure out how to have callbacks for each epoch. Is there a reason behind the choice of epochs?
#
# ### Description
#
# 1. Outputs are compatiable. Can run tagger for RE parts.
# 2. Fully integrated biobert to pipeline. Fix needed for the eval parts but those are doable.
# 3. Output should be taken in docria layers
#
#
# ### Results/Conclusions
# 1.
#
#
# ### Next Steps
# Build docria output. Already have an infrastructure ready in my notebooks for docria runs.

# %% [markdown]
#  # 7-9th June
# ---
# ### Project
# NLP pipeline
#
# ### Aim
# Build the pipeline in 1 week - finalize in the next. Write paper.
#
# ### Description
# Things got a little delayed due to prepping for the conference. Yet made little progress here and there.
#
# 1. Fixed output aggregation.
# 2. Added BERT to pipeline, fixed output to match petter-alexander json style (although I don't like it)
# 3. Downloaded NLM-gene annotated corpora: https://www.sciencedirect.com/science/article/pii/S1532046421001088?via%3Dihub
# this can be used to evaluate gene model. We can use similar cell, chemical, disease and species corpora for evaluation.
# 4. Trying to fix callback issues for training, eval and test
# 5.
#
#
# ### Results/Conclusions
# 1.
#
#
# ### Next Steps

# %% [markdown]
#  # 31st Aug
# ---
# ### Project
# NLP pipeline
#
# ### Summary
# Overall summary of the tasks so far:
#
# 1. Finished the pipeline. Fixed aggregration.
# 2. Ran over cell death corpus to check validity. Determined that its quite well streamlined.
# 3. Checked analysis script. The analysis was done on all possible combinations for each sentence (and not only entities) on finiding Point Mutual Information. Asked sonja for explanation.
# 4. Converted CORD 19, 2022-06-02 into docria format. PMC JSON articles. We have PDF - 401270 json (new: 20268, removed: 436)  PMC - 315742 json (new: 16260). From that only PMC has been converted.
# 5. Opened a word file and started the manuscript. Added bibtext to mendeley.
#
# ### To do
# 1. fix eval file and Gold standard
# 2. Write manuscript
# 3. Check RE parts
# 4. Write script to compare multi layer prediction
# 5. Freq table for entities
# 6. Compare test results
#
#
# ### Results/Conclusions
# 1.
#
#
# ### Next Steps

# %% [markdown]
#  # 1st Sep
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# Overall summary of the tasks so far:
#
# 1. Writing skeleton, methods and rest
#
# ### Description
# 1.
#
#
# ### Results/Conclusions
# 1.
#
#
# ### Next Steps

# %% [markdown]
#  # 2nd Sep
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# 1. Writing
#
# ### Description
#
# Note: a few things to look at:
#
# 1. Language models vs NER models
# 2. Conll eval script (perl?)
# 3.
#
#
# ### Results/Conclusions
# 1.
#
#
# ### Next Steps

# %% [markdown]
#  # 5th Sep
# ---
# ### Project
# NLP pipeline
#
# ### AIM
#  Eval + writing
#
# ### Description
#
# 1. Cell line: Adam ola model was evaluated on dev set, Salmas model was fine tuned on disease (WHY) therefore salma's biobert base model was chosen
# 2. Chemical best models (flair etc) were not trained on the HUNER corpora but BC5CDR etc. The best model is biobert base by both me and salma
# 3. Disease my model, rest are not HunFLAIR
# 4. Gene my model
# 5. Species salmas models are better but they're large models and double trained. Should we look into that? Otherwise biobert base models are actually good.
#
# overall, biobert is good not because they are actually good (some cases they are) but because the flair runs are on smaller datasets and not HUNER corpora
#
# onto the next?
#
#
#
# ### Results/Conclusions
# 1.
#
#
# ### Next Steps

# %% [markdown]
#  # 6th Sep
# ---
# ### Project
# NLP pipeline
#
# ### AIM
#  Eval + writing
#
# ### Description
#
# 1. BioBERT uses trainer evaluation, I planed to do the same to keep up with the rest but that is not plausible. Since biobert runs do_predict fx on the ner_dataset and I need to test on the existing test files and GS
#
# 2. Created an environment on Berzelius and ran loader + splitter on CORD 2022-06-02. Received a memory issue on normal so added 10 GPUs with spacy. Run for 2 days, not sure if this is enough
#
#
#
#
# ### Results/Conclusions
# 1.
#
#
# ### Next Steps

# %% [markdown]
#  # 7th Sep
# ---
# ### Project
# NLP pipeline
#
# ### AIM
#  Eval + writing
#
# ### Description
#
# 1. Created a frequency count file that counts term frequencies per article and per file for NER results (JSON->txt)
#
# 2.Created a dictionary of classes to compare differences between different NER results. of course it can be converted to docria. But docria requires an additional
#
#
# ### Results/Conclusions
# 1.
#
#
# ### Next Steps

# %% [markdown]
#  # 22nd Sep
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# Process
#
# ### Description
# So far the following things have not been noted:
# 1. Writing the manuscript
# 2. Added frequency count script to evals
# 3. Fixed Loader memory issue by splitting sentences into batches.
# 4. Worked on fixing docria to load documents in layers
#
#
# Now current tasks include
# 1. Fixing multiprocessing parts
# 2. fixing evaluation of gold standard part
# 3. fixing docria parts
# 4. adding flair to the mix
# 5. Writing the doc
# 6. Running cord on server
# 7. Running cell death on server
#
#
# ### Results/Conclusions
# 1. Once these are done, the paper is done
#
#
# ### Next Steps

# %% [markdown]
#  # 23rd Sep
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# Meeting
#
# ### Description
# So far the following things have not been noted:
# 1. Ask Salma to upload the NER results - Done
# 2. Evaluation can be done by getting say protein biobert vs protein flair and counting their intersection over union
# 3. Sonja can look through sentences and check if the entities actually match.
# 4. Ar the errors from both models same? say 20% wrong?
# 5. Send JSON file and frequency table to sonja
# 6. add best models to a new sheet in one drive
# 7. Overlap should be considered among GS and test sets.
# 8. Individual consultation academic support
# 9. Structured writing for paper: this paragraph conveys this message
# 10. Spacy Phrasematcher output on GS.
# 11. MTOR and TSC1 for proof of concept.
# 12. Write result section first.
# 13. Check original hunflair paper table with best models. Check if they use precision recall or something else
# 14. Update portfolio.
#
#
# Now current tasks include
#
#
#
# ### Results/Conclusions
# 1. Once these are done, the paper is done
#
#
# ### Next Steps

# %% [markdown]
#  # 26th Sep
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# Meeting + work
#
# ### Description
# So far the following things have not been noted:
# 1. How many abstracts is a term found (along with freq?)
# 2. Later we apply named entity linking with the NER
# 3. Add to manuscript: With protein model we not only find individual genes and proteins, but also collection terms like "growth factor" and " kinase.
# 4. Check spacy splitter = works fine
# 5. To do: post processing for merging NER files.
# 6. Proteins misclassified as chemical is a problem. However, if it is 6/2900 it is not, if it is 6/60 then it is.
# 7. Add in the methods section that titles were not processed.
# 8.
#
#
# What I have done:
# 1. Frequency counts/batch
# 2. Added free text loader script
# 3. Discussed results and commoun outcomes
#
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps
# to do:
# 1. 1 term appears in how many docs?
# 2. Manage NER batches
# 3. Cord multiprocessing
# 4. Flair loading
# 5. Manuscript editing that sonja has commented on.
# 6. GRANT!!
# 7. Evaluations on GS

# %% [markdown]
#  # 28th Sep
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# Flair chaos
#
# ### Description
# 1. Flair doesnt load. Dependencies indicate issues with version
# 2. Flair doesnt install to nlp_gpu env
# 3. Now what?
#
#
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
#  # 6th Oct
# ---
# ### Project
# Dev Meeting
#
# ### AIM
#
#
# ### Description
# 1. Write a list of 20 companies in different levels and send to sonja
# 2. Write multiple manuscripts for publication
# 3. Let sonja know about updates frequently (1 line msg)
# 4. Planner update 2 day jobs
# 5. Biology primers
# 6. Improve soft skills (writing, proj. management, productivity)
# 7. Write continuously every day
# 8. Watch lectures regularly
# 9. 1 paper at least per week
# 10. Think about COMPUTE mentor program and how do I want it to be.
# 11. Journal club
#
#
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
#  # 6th Oct
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# NLP Pipeline
#
# ### Description
# 1. Manuscript fix
# 2. Write code on cord mp
# 3.
#
#
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
#  # 11th Oct
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# NLP Pipeline
#
# ### Description
# 1. Flair fix: tried running flair on a separate environment, did not work. Will get back to that later. Maybe ask salma to run that part or run on linux
# 2. Tryinng to implement
#
#
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
#  # 21st Oct
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# NLP Pipeline - splitter parallel processing
#
# ### Description
# 1. parallel processing done in batches with both spacy and nltk
# 2. NER parallel processing not done yet.
#
#
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
#  # 24th Oct
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# NLP Pipeline
#
# ### Description
# 1. Fixed NER multiprocessing. Should work in parallel now. Extensive testing not done
# 2. Article limit needs to be added to splitter
# 3. Need to test phrasematcher as well
#
#
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps
# 1. Eval GS
# 2. Proof of concept MTOR and TSC1 (or cell death)?
# 3. CORD full abstracts split and predict
# 4. Frequency count per doc edits
# 5. Merge entities
# 6. Manuscript

# %% [markdown]
#  # 27th Oct
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# NLP Pipeline
#
# ### Description
# Attended the artificial cognition by AI lund
#
# nlp parts:
#
# 1. GS test?
# 2. CORD progress
# 3. Write paper
#
#
# GS evaluation has issues since the scores are very low. One immidiate solution could be loss tracking. Another? idk
# Need to line up GS to check scores and evaluate... maybe on craft
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
#  # 31st Oct
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# NLP Pipeline
#
# ### Description
# 1. Writing first proper draft
# 2. It was mostly writing all day
# 3. Need to include cord results in manuscript
#
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
#  # 1st Nov
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# NLP Pipeline
#
# ### Description
# 1. splitting batch giver error due to GPU im guessing
# 2. The NLP GPU environment failed. Need to fix cuda
#
#
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
#  # 2nd Nov
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# NLP Pipeline
#
# ### Description
# 1. Skipped local GPU for now. Ran cord split on berzelius
# 2. Berzelius generated 765 files = 765000 articles... what happened to the other 55000 articles??
# 3. WHAT HAPPENED????????
#
#
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
#  # 3rd Nov
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# NLP Pipeline
#
# ### Description
# 1. working on entity_merger script
# 2. Looked at why cord gives 765k article... because there are duplicates within the file
#
#
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
#  # 4th Nov
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# NLP Pipeline
#
# ### Description
# 1. working on entity_merger script
# 2. Entity merger finished with glob.glob part to be added
#
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
#  # 7th Nov
# ---
# ### Project
# NLP pipeline - CUDA
#
# ### AIM
# NLP Pipeline
#
# ### Description
# 1. CUDA not working on berzelius with the pytorch version, something along the lines of A100 only allows sm80 pytorch
# 2. https://stackoverflow.com/questions/66992585/how-does-one-use-pytorch-cuda-with-an-a100-gpu says that cuda version 11.0 is required. Deleted old packages and installed 11.0 stable again. Need to write a blog post about it
# 3. Tried a bunch of things before. Installed 11.7 in my laptop with cuda but pytorch still returns false
# 4. For my laptop, it turns out cudnn should be additionally installled for pytorch (through conda install -c anaconda cudnn). Then it works. installs cuda 11.3.1 and cudnn 8.2. list with conda list cudnn
# 5. For the cluster it may be the same
#
#
# ### Results/Conclusions
#
#
#
# ### Next Steps

# %% [markdown]
#  # 8th Nov
# ---
# ### Project
# NLP pipeline - CUDA
#
# ### AIM
# NLP Pipeline
#
# ### Description
# 1. Changed conda environment and packages paths (because berzelius storage was capping) using conda config --append /proj/berzelius-2021-21/users/rafsan/rafsan_envs/ and conda config --pkgs_dirs path and showing with conda config --show
#
# 2. Installed an environment as follows:
# conda create -name ner39 python=3.9
# conda activate ner39
# conda install pytorch torchvision torchaudio pytorch-cuda=11.7 -c pytorch -c nvidia
# pip install seqeval
# conda install transformers
#
# transformers library version 4.24.0
# huggingface_hub 0.10.1
#
# running a job in interactive mode did not work
# however, submitting jobs worked just fine with great runtime
#
# 3. Trained species model Hunflair and trained without issue
#
#
#
#
# ### Results/Conclusions
# solver
#
#
# ### Next Steps
# Need to run trainer with early stopping OR callbacks

# %% [markdown]
#  # 9th Nov
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# NLP Pipeline BioBERT ner.py script + callbacks
#
# ### Description
# 1. Added EarlyStoppingCallback biobert script by
#     Training_args:
#     evaluation_strategy steps
#     load_best_model_at_end True
#     metric_for_best_model f1
#     eval_steps {NUM_STEPS}
#     logging_steps {NUM_STEPS}
#     warmup_ratio 0.1
#     save_total_limit 10
#
#
#     ner.py:
#     from transformers import EarlyStoppingCallback
#     in trainer: callbacks=[EarlyStoppingCallback(early_stopping_patience=30)]
#
#     runs fine
#
# 2.
#
#
#
#
# ### Results/Conclusions
# solver
#
#
# ### Next Steps
# Need to run trainer with early stopping OR callbacks

# %% [markdown]
#  # 14th Nov
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# NLP Pipeline BioBERT retraining
#
# ### Description
# 1. Noted for species that early stopping with 30 patience vs 50 patience does not necessarily improve
#
# 2. Realized that converting early stopping to epochs is better since the performance is expected to improve.
#
# 3. Cell models did not function too well. Change max_length to 128, then it ran well. How does it affect the overall runs?
#
#
#
#
#
#
# ### Results/Conclusions
# solver
#
#
# ### Next Steps
# Early stopping runs are done. Next is GS prediction that should take 20 mins maybe

# %% [markdown]
#  # 16th Nov
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# NLP Pipeline BioBERT retraining
#
# ### Description
# 1. Saw results of training models with 3 epoch patience. Graphs show that the models can be trained more.
# 2. So I trained 10 and 50 epoch patience. Awaiting results
# 3. Downloaded craft corpora. Found a script to process this at https://stackoverflow.com/questions/59261444/how-to-convert-xml-ner-data-from-the-craft-corpus-to-spacys-json-format
# 4.
#
#
#
#
#
# ### Results/Conclusions
# solver
#
#
# ### Next Steps
# Early stopping runs are done. Next is GS prediction that should take 20 mins maybe

# %% [markdown]
#  # 18th Nov
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# NLP Pipeline CRAFT
#
# ### Description
# 1. The files to look for is within the craft corpus genia-xml
# C:\Users\rafsa\Documents\AITSLAB\nlp_pipeline\rafsan\data\craft-2.0\genia-xml\term
# The files are annotated, however they need to be processed. So I am processing them
#
# 2.Prepped a job script with title job_GS to run GS evals. Turns out the GS IOB2 file needs to be split into each category for a final list of test corpora. Categories I found:
#
# ['cell',
#  'chemical',
#  'disease',
#  'disease_with_symptoms',
#  'disease_with_virus',
#  'disease_with_virus_and_symptoms',
#  'species',
#  'species_with_virus',
#  'protein']
#
# Chemical model seems to have only one term. Strange but not uncommon
#
# 3. The datasets first needed to be preprocessed by the bioBERT preprocess.sh script. THE TEST IS ONLY POSSIBLE IF THE PREPROCESS SCRIPT HAS BEEN RUN THROUGH THE TEST FILE. Max seq length was set as 128. Which reminds me to run the CELL dataset through the preprocess script and retrain the cell model
#
# 4. Wrote a Bash Script for the GS runs for combined GS evaluation. Need to do one for combining the data but that should be easy.
# ```console
# #!/usr/bin/env bash
# #SBATCH -A berzelius-2022-219
# #SBATCH -n 1 --gpus 1
# #SBATCH -t 1:00:00
# #SBATCH -J biobert_test_GS
# #SBATCH --mail-user=rafsan.ahmed@med.lu.se
# #SBATCH --mail-type=END
# #SBATCH -o train.out
# #SBATCH -e train.err
# export SAVE_PATH=/proj/berzelius-2021-21/users/rafsan/alvis/rafsan/biobert_main/pytorch-biobert/biobert_pytorch_retrain/output_GS_epochs
# export DATA_PATH=/proj/berzelius-2021-21/users/rafsan/alvis/rafsan/gold_std_iob2_sonja
# export MAX_LENGTH=192
# export ENTITY=HunFlair_disease_all
# export SEED=1
# for DATA_DIR in ${DATA_PATH}/*
# do
# TEST_SET=$(basename ${DATA_DIR})
# SAVE_DIR=${SAVE_PATH}/${ENTITY}/${TEST_SET}
# mkdir -p ${SAVE_DIR}
# python /proj/berzelius-2021-21/users/rafsan/alvis/rafsan/biobert_main/pytorch-biobert/biobert-pytorch/named-entity-recognition/run_ner.py \
#     --data_dir ${DATA_DIR}/ \
#     --labels ${DATA_DIR}/labels.txt \
#     --model_name_or_path /proj/berzelius-2021-21/users/rafsan/alvis/rafsan/biobert_main/pytorch-biobert/biobert_pytorch_retrain/output_retrain_epoch_50/${ENTITY} \
#     --output_dir ${SAVE_DIR}\
#     --max_seq_length ${MAX_LENGTH} \
#     --seed ${SEED} \
#     --do_predict \
#     --overwrite_output_dir
# done
# ```
#
#
#
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
# CRAFT looks good. Also RAREDIS seems like something I want to look at

# %% [markdown]
#  # 21st Nov
# ---
# ### Project
# NLP pipeline
#
# ### AIM
# NLP Pipeline GS and CRAFT
#
# ### Description
# 1. Cell models seem to have an issue with max seq length. The reason being them not being preprocessed by the biobert script (convert to txt etc). Therefore, I have tried the preprocessing step again but got indexing errors similar to the already trained model. So, Kept to the same model and did not retrain the model.
#
# 2. Craft process/preprocess aaaand? rest?
#
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
# Meeting with sonja tomorrow

# %% [markdown]
#  # 22st Nov
# ---
# ### Project
# NLP pipeline meeting sonja
#
# ### AIM
# NLP Pipeline GS and CRAFTmanuscript + portfolio
#
# ### Meeting with Sonja
# 1. Go through methods section and fix it. Explanations should be on results section not the methods as sonja suggests
#
# 2. BMC bioinformatics check author guidelines about result and method sections
# "We chose the huner corpora because they use a combination of corpora that allows better generalization" in the result section
#
# 3. Figure with pipeline structure
#
# 4. Mention config file in the pipeline section
#
# 5.One sentence in results section like "many NER models perform poorly when applied to text collection other thant the type of texts. They were trained on the "
#
# 6. Clarify why we trained 5 individual models but not 1 because HUNER is a collection of collections.
#
# 7. Double check if hunFLAIR model evaluations were calculated in the same way as BioBERT
#
# 8. HUNER check if they have a script for conversion already
#
# 9. How BIOBERT tokenization happens on prediction
#
# 10. Print prediction steps of the biobert script
#
# 11. HunFlair evaluation script - really understand how it is working
#
# 12. Plot F1 score for all models
#
# 13. Train large chemical models
#
# 14. BC5CDR train biobert and run on GS++
#
# 15. Ranked results in the supplementary results
#
# 16. Table of ranked output in the supplementary
#
# 17. Put all models in the XL NER table
#
# 18. BC5CDR is in hunflair
#
# 19. Prediction on GOLD std free text
#
# ### Description
#
# 1. Trained biobert large model on chem
#
# 2. Trained BC5CDR chem and disease models
#
# 3. Checked Corpora vs Test results
#
# | entity | train terms (lines) | eval terms (lines) | test terms (lines) | precision | recall | f1 |
# | --- | --- | --- | --- | --- | --- | --- |
# | chemical | 2975453 | 487065 | 1496407 | 0.87555 | 0.87611 | 0.87583 |
# | disease | 559179 | 89269 | 270437 | 0.82358 | 0.84487 | 0.83409 |
# | gene | 2885678 | 474491 | 1407703 | 0.75726 | 0.78151 | 0.76919 |
# | species | 894201 | 150534 | 393823 | 0.78931 | 0.73724 | 0.76239 |
# | cell | 578265 | 98357 | 279826 | 0.64066 | 0.63740 | 0.63903 |
#
#
# 4. BC5CDR-disease model gets an f1 score of 0.86 which is better than the HUNER-disease sub corpus. For BC5CDR-chem the result is 0.9288, much higher than 0.875 of the HUNER sub corpus. But of course the test sets are different. So the results are NOT comparable.
#
# 5. Ran GS on BC5CDR-disease on disease, disease_with virus, symptoms and both. F1 scores are:
# | entity | HunFlair_disease | BC5CDR-disease |
# | --- | --- | --- |
# | disease | 0.35 | 0.33 |
# | disease_with_symptoms | 0.672 | 0.644 |
# | disease_with_virus | 0.208 | 0.182 |
# | disease_with_virus_and_symptoms | 0.417 | 0.382 |
#
# ### Results/Conclusions
#
#
# ### Next Steps
# Some good results

# %% [markdown]
#  # 1st Dec
# ---
# ### Project
# NLP pipeline
#
# ### AIM
#
#
# ### Description
#
# 1. over the last few days I have run cell and chem large models, plotted f1 curve vs loss and logged the trained models. I am going with the current patience 50 models since they are not too different from patience 10. Two models perform better for 10 where the rest are good for 50. Justification for this is unclear, but I want to use a well trained model instead of alternatives.
#
# 2. Large models give more or less the same results. Which is quite surprising.
#
# 3. I have looked at baseline biobert models and saw the predictions are super bad (0.03 f1 scores and such). So fine tuning was nice.
#
# 4. I checked the use of dev/eval set. Point of it was to evaluate the trained model and keep the best one. Eventually we end up with the overall best model.
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
# cord + gs

# %% [markdown]
#  # 2nd Dec
# ---
# ### Project
# NLP pipeline
#
# ### AIM
#
#
# ### Description
#
# 1. Ran chemical on cord abstracts by opening ner_v2 environment and running chem epoch 50 on cord. Made some minor updates to the code. Seems to run ok.
#
#
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
# cord + gs

# %% [markdown]
#  # 5th Dec
# ---
# ### Project
# NLP pipeline
#
# ### AIM
#
#
# ### Description
#
# 1. NER fix on formatting and range. Config addition of article limit seems to work ok
# 2. Copied patience 50 epoch models to my computer for cell deathh and mtor&tsc1 runs?
# 3. Haven't copied due to current job, but expecting failure
#
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
# cord + gs

# %% [markdown]
#  # 6th Dec
# ---
# ### Project
# NLP pipeline
#
# ### AIM
#
#
# ### Description
#
# 1. Broke down whole cord processing into smaller 128 gb, 64 core tasks. Memory seems ok and 6 jobs were run
# 2. Seems to be a solution.
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
# cord + gs

# %% [markdown]
#  # 7-8th Dec
# ---
# ### Project
# NLP pipeline
#
# ### AIM
#
#
# ### Description
#
# 1. Cord generated files in batches. Waiting for the entire process to finish. Files need to be renamed because Accidentally named the chem nmodels "cell", the simple linux command to change them seems to be "
#
# ```console
# rename str str_replace *json"
# ```
# 2. Cord output had unicode errors. Some batches were not processed due to only unicode escape characters existing in the text(sentence) and BERT considering it as empty string which are not tokenize and therfore errors. After trying different things unsuccessfully I have applied a simple try except method to try running prediction and if not dont do anything. This seems to work quite well and only affects one sentence in the batch. Sometimes simplest approaches are the best :p
#
# example: {"text": "\u200f"}
#
# 3. Running leftover cord chem predictions. Will follow that with the remaining entities. Fun fact, each batch of 1000 articles takes 17-20 minst to process, while 1000 batches took roughly 24 hours for chem. I wonder how gpu plays a role here. When processing is done on two multiprocess, suddenly 17-20 minutes become 1.5 hours
#
# 4.
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
# 1. Start working on cell death and autophagy 1000 datasets
# 2. Check out entity merger file
# 3. Manuscript

# %% [markdown]
#  # 12th Dec
# ---
# ### Project
# NLP pipeline
#
# ### AIM
#
#
# ### Description
#
# 1. Submitted all cord NER jobs. Checked that some files were missing, probably due to manual error. Fixed them.
# 2. Working on Lund autophagy and cell death datasets.
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
# 1. Start working on cell death and autophagy 1000 datasets
# 2. Check out entity merger file
# 3. Manuscript

# %% [markdown]
#  # 13th Dec
# ---
# ### Project
# NLP pipeline
#
# ### AIM
#
#
# ### Description
#
# 1. Attended the writing thesis summary
# 2. Downloaded pubmed ID of search results with "autophagy" AND "cancer" for articles between 2020 and 2023 today. I got 8333 papers
# 3. Ran the pipeline on the papers. Note that the cell death cohort was a collection of 1000 papers with mtorandtsc1 on may 24th
# 4. The downloader fails to load all articles at once sometimes. Running it again solved the issue
#
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
# 1. Check out entity merger file
# 3. Manuscript

# %% [markdown]
#  # 14th Dec
# ---
# ### Project
# NLP pipeline
#
# ### AIM
#
#
# ### Description
#
# 1. created test_run_analysis2 with large dictionary structure
# 2.
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
# 1. Check out entity merger file
# 3. Manuscript

# %% [markdown]
#  # 10th Jan
# ---
# ### Project
# NLP pipeline
#
# ### AIM
#
#
# ### Description
#
# Following are the resources for spacy phrasematcher:
# 1. https://github.com/Aitslab/BioNLP/tree/master/sonja/dictionairies
# 2. https://github.com/Aitslab/corona/tree/master/dictionaries
#
# 3. Mariam (and some students before her) wrote code for extracting all of the names in uniprot and the human genome database: https://github.com/mariamsm1/ShortProject2020/tree/master/Uniprot_HGNC_data
#
# 4. and Antton wrote code to extract the MONDO disease names: https://github.com/AnttonLA/BINP37/tree/8f875fdb9b886bcd28db96bfc80340fc99f8cb0f/mondo
#
# 5. Annie wrote some code for the NCBI taxonomy database. Maybe you can find her folder on LUNARC
#
# ___
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
# 1. Check out entity merger file
# 3. Manuscript

# %% [markdown]
#  # 11th Jan
# ---
# ### Project
# NLP pipeline
#
# ### AIM
#
#
# ### Description
#
# Tried spacy with supplementary file 2 from the covid GS paper repo. Tested it on autophagy1 and 2 corpora
#
# works pretty well. Need to apply it to cord 19
#
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
# 1. Check out entity merger file

# %% [markdown]
#  # 13th Jan
# ---
# ### Project
# NLP pipeline
#
# ### AIM
#
#
# ### Description
#
# 1. Huner uses macro average precision recall f1 from scores obtained from conll evaluation (perl) script. We don't use conlleval. Are they comparable with current data?
# https://github.com/hu-ner/huner/blob/c58c47579a52ebd01934142dedfda30bc9747ec4/evaluation/conlleval
#
# 2. There may be an error within the train test scattertext because of BIO tags. BI = whole entity but ew take each entity at a time
#
# 3. Gold standard evaluations:
#     a. Disease: disease_covid19 + disease_other = disease
#     b. Species: species_human + species_other + virus_family + virus_other + virus_SARS-CoV-2 = species with virus
#     c. gene: protein = protein
#
# 4. Sonja asked to add biobert large models with warmup to the table. However, I trained only two large model with chemical and cells with 10 epochs early stopping and the results were similar to the biobert base.
#
# 5.
#
#
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
# 1. Check out entity merger file

# %% [markdown]
#  # 19th Jan
# ---
# ### Project
# NLP pipeline -train dev error
#
# ### AIM
#
#
# ### Description
#
# 1. The biobert p50 (epoch 50) models are trained on train_dev instead of train as previously intended. The issue was with the split class in the utils (pytorch-biobert) that uses the train_dev instead of train
#
# 2. THis means that early stopping theory of generalization does not work as there is a leak from the train_dev and evaluation is done on dev.
#
# 3. Models need to be retrained etc
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
# 1. Check out entity merger file

# %% [markdown]
#  # 13th Mar
# ---
# ### Project
# NLP overview
#
# ### AIM
#
#
# ### Description
#
# 1. Had halftime. Document submission still remaining.
#
# 2. Had development chat. A few pointers:
#     a. Travel grant for travel
#     b. Conference to use travel grant
#     c. Need drive for everything
#     d. Sysbio + NLP papers every week
#     e. Write blog
#     f. Agile
#
# 3. Finish up manuscript. Finalize pipeline
#
# 4. Working on
#     a. Fininshing manuscript
#     b. agile
#     c. GNN
#     d. Few shot learning
#     e.
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
# 1. Check out entity merger file

# %% [markdown]
#  # 14th Mar
# ---
# ### Project
# NLP overview
#
# ### AIM
#
#
# ### Description
#
# 1. Check conferences through IEEE and conference index. A few names like biocreative, bioNLP etc popped out. Nothing certain yet.
#
# 2. Checked grants. fysiografen seems like the safest bet. Although they require publication.
#
# 3. Mentlife application done
#
# 4. ??
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
# 1. Check out entity merger file

# %% [markdown]
#  # 17th Mar
# ---
# ### Project
# NLP overview
#
# ### AIM
#
#
# ### Description
#
# 1. Meeting with sonja about NEL and chatGPT: https://github.com/Aitslab/CIRP/issues/4. Sonja's code seems functional. But dictionary based approach is needed for large datasets like cord
#
# 2. GS/BC5CDR work + manuscript - continuation: Added figures + GS numbers and continuing with the rest
#
# 3. The tokenizer used for GPT is tiktoken: https://github.com/openai/tiktoken
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
# Finalizing the manuscript.

# %% [markdown]
#  # 20th Mar
# ---
# ### Project
# NLP Pipeline
#
# ### AIM
#
#
# ### Description
#
# 1. Using HUNER repo for craft evaluation: https://github.com/hu-ner/huner/blob/master/ner_scripts/convert_craft.sh
#
# 2. check package version with
#
# ```python
#     import transformers
#     transformers.__version__
# ```
#
# 3. On WILLIAM SciSpacy models: I am not exactly sure if they can be used. First of all, the Lund COVID-19 corpus was created for the NLP paper by looking at individual entities (disease, protein, species with virus). On the other hand it seems like William ran his evaluations it seems that disease and protein are fine but species includes only virus and not human. Also I don’t have the models to run them. If we are certain of his approaches we can use the disease and gene models.
# https://github.com/Aitslab/BioNLP/blob/39c1deef143395d9469eae997820d481e285d915/evaluation/william/NER_Scispacy_William/NER_Scispacy_William_final.ipynb
#
# 4. For craft OpenNLP and Apache maven had to be installed in my computer:
#
#     For windows first download and unzip the apache maven (extractable binary zip): https://phoenixnap.com/kb/install-maven-windows
#
#     Then download and unzip opennlp *bin*: https://www.tutorialspoint.com/opennlp/opennlp_environment.htm
#
# 5.
#
# ### Results/Conclusions
#
#
# ### Next Steps
# Finalizing the manuscript.

# %% [markdown]
#  # 21st Mar
# ---
# ### Project
# NLP Pipeline - craft etc
#
# ### AIM
#
#
# ### Description
#
# 1. Craft didn't work for several reasons. I had to make a change to craft to conll file (https://github.com/hu-ner/huner/blob/master/ner_scripts/scripts/craft_to_conll.py) by specifying the path to OPENNLP to the bin folder in my computer. Also by setting subprocess to "shell=True" in the opennlp wrapper file (https://github.com/hu-ner/huner/blob/master/ner_scripts/scripts/opennlp_wrapper.py).
#
# 2. WSL didn't work. Something with sudo.
#
# 3. Sonja asked me to run predictions (v1,v2) on train and dev sets of the huner corpora.
#
# 4. Downloaded models from: https://opennlp.sourceforge.net/models-1.5/ as per huner instructions for craft. Save them in a "models/" folder in "C:/apache-opennlp-2.1.1/"
#
# 5. Error:  spaces = self.sentence_offsets[id+1]-self.sentence_offsets[id]-len(self.sentences[id])
# IndexError: list index out of range
#
#
#
# ### Results/Conclusions
# Couldnt finish up since the script didnt work. Sentences get split but there is the #5 error. Need to find other options perhaps or edit the script (edited some already)
#
# ### Next Steps
# Finalizing the manuscript.

# %% [markdown]
#  # 22nd Mar
# ---
# ### Project
# NLP Pipeline - craft etc
#
# ### AIM
#
#
# ### Description
#
# 1. Tried chatGPT with promts to get a managable script to start with, if I was to rewrite the HUNER/CONLL/OPENNLP script. Have something that may work. Need to explore it more
#
# 2. Wrote an issue:https://github.com/hu-ner/huner/issues/31
#
# 3. Started with the CIRP github:https://github.com/Aitslab/CIRP/
#
#     a. MD: added quick start
#     b. Code edits: some path etc work needs to be done but I will leave it for later
#     c. Tutorials: One notebook is written. It needs to be evaluated (but it is something).
#
# Sonja wrote, github documentation should include instructions for how to use the pipeline with pre-trained models and dictionaries and instructions for how user-developed models and dictionaries can be deployed. also include instructions for how to repeat model training: 1. Environment setup. 2. Huner corpus acquisition and preprocessing, 3. BioBERT acquisition and training. 4. BioBERT model evaluation.
#
# 4. Ran predictions on train, dev on all huner corpora for v1 and v2. Adjusted the manuscript.
#
# 5. Looked at craft again and annotation. The annotations are separate and somehow the offsets are used to get full text. Not exactly sure how it is done, but need to look more into it.
#
# 6. Checked scispacy models. If I can get craft working then it will be immensely useful for all eval. Scispacy needs to be evaluated on LUND Covid19 corpus as well. How, not sure. William has a script that may be useful: https://github.com/Aitslab/BioNLP/blob/master/evaluation/william/NER_Scispacy_William/NER_Scispacy_William_final.ipynb
#
# ### Results/Conclusions
# 4/12 steps remaining for submission. So far so good. Marcus didn't reply. Need to double check the code Salma has
#
# ### Next Steps
# Finalizing the manuscript.

# %% [markdown]
#  # 24th Mar
# ---
# ### Project
# NLP Pipeline
#
# ### AIM
#
#
# ### Description
# Sonja suggested checking out craft data used by students. I checked the one by nicholas: https://github.com/Aitslab/BioNLP/tree/master/nicolas and the data: https://lunduniversityo365.sharepoint.com/:u:/r/sites/CDLAI_EDAN70/Delade%20dokument/General/CRAFT-conll.zip?csf=1&web=1&e=eiWttS
#
# the data seem to be coreference only and does not have tags for chem, gene or species. I checked nicholas's paper (link in github) but that doesn't describe much about it.
#
# I am not sure I can use the data
#
# I have been going through the script from huner craft and it seems to work with id-1 for sentence merger (offset). I will try it once more to see if it can work
# ### Results/Conclusions
#
#
# ### Next Steps
# Finalizing the manuscript.

# %% [markdown]
#  # 27th Mar
# ---
# ### Project
# NLP Pipeline
#
# ### AIM
#
#
# ### Description
# I looked at the huner craft script and figured that the pexpect library can only be successfully run in linux (not windows). Otherwise we get a "spawn" error.It is a documented error that the developers themselves mentioned. So now I move things to the cluster.
#
# I also checked craft wiki for other data: https://github.com/UCDenver-ccp/CRAFT/wiki/Alternative-annotation-file-formats. CONLL is only available for coreference and not concept annotations. In the end I may have to write it myself from scratch.
#
# The reason why it is important is the tokenization aspect of opennlp. Simply using spacy and generating IOB file wont work.
#
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
# Finalizing the manuscript.

# %% [markdown]
#  # 28th Mar
# ---
# ### Project
# NLP Pipeline craft
#
# ### AIM
#
#
# ### Description
# Success! Found a way to use spacy to use the craft v4 file and create an IOB2 format
#
# How?
#
# 1. Use the script at https://github.com/UCDenver-ccp/CRAFT/wiki/Alternative-annotation-file-formats to convert craft-4.0.0
# into pubannotation json format (started with CHEBI)
# ex: boot
# 2. Use spacy doc and manually add the entities to the doc (set_ents[span1,span2...]). I will add the script to the pipeline.
#
# 3. Create the file with iob tags
#
# 4. Going back to opennlp, I initially thought about using the OPNENLP tokenizer in the HUNER crafttoconll file. but the pexpect library does not work in windows. I triend wexpect as well but there are too many error. I tried cluster too but for some reason opennlp is not loaded as executable. The solution seems to be a docker environment, but that would take mode time. I decided to go with spacy instead. It seems to be good enough tokenization. I will add a step for error checking.
#
# 5. Entrez gene considered in HUNFLAIR is PR (protein ontology) in the craft corpora.
# Explanation: Looking at the conversion of the craft corpora by HUNER, the entrez gene database is considered as the gene/protein one they compare with. HOWEVER, there is no entrez gene database in V4 (same one they benchmark), but there is a folder called PR. That is the one.
#
# 6. I realized that some tokenization on the craft file did not work as intended. Because tokenization from spacy doesn't exactly match the intended tokenization. So when I tried setting up entities, it caused issues. Because overlaps, fragments and duplicate annotation (partially due to the nature of the tokenization. I simply allowed an expanded tokenization for given spans, meaning when I load the span from the craft 4.0.0 file, if that doesnt match the token, then I expand to the token where the span is found. Summerized script is below. Expanded script will be attached to the pipeline.
#
# ```python
# span=doc.char_span(start, end, label=label, alignment_mode="expand")
# doc.set_ents(entities=spans)
# ```
#
# 7. Ran jobs on the curated craft corpora. Preprocessing was needed before the prediction could be run.
#
# chemical and species worse, gene better
#
# 8.
#
# ### Results/Conclusions
#
#
# ### Next Steps
# Finalizing the manuscript.

# %% [markdown]
#  # 29th Mar
# ---
# ### Project
# NLP Pipeline
#
# ### AIM
#
#
# ### Description
# 1. Asked Salma to run predictions with hunflair base model(s) on craft v4.0.
#
# 2. Finalizing manuscript and github
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
# Finalizing the manuscript.

# %% [markdown]
#  # 30th Mar
# ---
# ### Project
# NLP Pipeline
#
# ### AIM
#
#
# ### Description
# 1. Salma added this script to process the corpora to add newline after ". O":
#
# ```console
# !cat ../20230328_RA_nlpeng_craft_4.0.0_processed/NCBItaxon_species_spacy_custom/test.tsv | sed s/'^\.\tO'/'\.\tO\n'/g
# ```
#
# 2. Added craft preprocessing script to github: https://github.com/Aitslab/CIRP/blob/main/supplementary/preprocessing_scripts/CRAFT_preprocessing_spacy.py
#
# 3. Addressed comments on manuscript
#
# ### Results/Conclusions
#
#
# ### Next Steps

# %% [markdown]
#  # 31st Mar
# ---
# ### Project
# NLP Pipeline
#
# ### AIM
#
#
# ### Description
# 1.
#
# ### Results/Conclusions
#
#
# ### Next Steps

# %% [markdown]
#  # 3rd Apr
# ---
# ### Project
# NLP Pipeline ++
#
# ### AIM
#
#
# ### Description
# 1. Fixed figures on the paper.
#
# 2. Manuscript ready (I think)
#
# 3. Found paper, sent ou Journal Club emails. Added to calendars
#
# 4. Looked at portability and docker
#
# 5.
#
# ### Results/Conclusions
#
#
# ### Next Steps

# %% [markdown]
#  # 4th Apr
# ---
# ### Project
# NLP Pipeline
#
# ### AIM
#
#
# ### Description
# 1. Addressed sonjas comments on the paper about dates and links
#
# 2. Double checked hunflair vs seqeval results and they were same (checck manuscript)
#
# 3. Asked salma to run hunflair on gold standard
#
# 4. Tried running scispacy models on simplified lund cord-19 corpora
#
# ### Results/Conclusions
#
#
# ### Next Steps

# %% [markdown]
#  # 5th Apr
# ---
# ### Project
# NLP Pipeline
#
# ### AIM
#
#
# ### Description
# 1. Got salmas numbers for GS
#
# 2. Ran scispacy models -
#     a. Convert IOB (ex. protein) tags to I-PROTEIN, B-PROTEIN, O tags
#
#     b. RUn spacy conversion: python -m spacy convert data/gs_iob2_sonja_spacy/temp_protein.txt data/gs_iob2_sonja_spacy -c ner
#
#     c. Load .spacy file into a docbin
#
#     d. Use nlp sci to load and nlp whatever to run predictions
#
#
# ### Results/Conclusions
#
#
# ### Next Steps

# %% [markdown]
#  # 6th Apr
# ---
# ### Project
# Meeting
#
# ### AIM
#
#
# ### Description
# 1. Got salmas numbers for GS
#
# 2. Applied to LU symposium
#
# 3. Troubleshoot Berzelius user registration for peter and jacob
#
# 4. Added scispacy evaluations to paper
#
# ...off to easter break
# ### Results/Conclusions
#
#
# ### Next Steps

# %% [markdown]
#  # 12th Apr
# ---
# ### Project
# NLP Pipeline
#
# ### AIM
#
#
# ### Description
# 1. Made changes to the github repo: Added tutorial, notes, fixed readme and such. Adding images still need to be fixed. The pipeline is now called LUMINER
#
# 2. Added huggingface organization: https://huggingface.co/aitslab
#
# 3. Uploaded models to hf hub
#
# 4. Checked the spaces part a bit. need streamlit demo
#
#
# for highlighting use
# ```
# <mark>Marked text</mark>
# ```
# ### Results/Conclusions
#
#
# ### Next Steps

# %% [markdown]
#  # 13th Apr
# ---
# ### Project
# NLP Pipeline
#
# ### AIM
#
#
# ### Description
# 1. Journal club prep and presentation
#
# 2. Github fix: Search, readme ++
#
#
#
# ### Results/Conclusions
#
#
# ### Next Steps

# %% [markdown]
#  # 17th Apr
# ---
# ### Project
# NLP Pipeline
#
# ### AIM
#
#
# ### Description
# 1. Github: update search and fix config
#
# 2. Docker needs switchdaemon:
#
# ```
# & 'C:\Program Files\Docker\Docker\DockerCli.exe' -SwitchDaemon
# ```
#
# 3. Docker needs wsl 2. THis can be done by
#
# ```
# wsl.exe --set-version (distro name) 2
#
# ```
#
#
# ### Results/Conclusions
#
#
# ### Next Steps

# %% [markdown]
#  # 24th Apr
# ---
# ### Project
# NLP Pipeline
#
# ### AIM
#
#
# ### Description
# 1. Docker run container with local port using docker run -i -t -p 8080:8080 continuumio/miniconda3 /bin/bash
#
# 2. Created a dockerfile in the following format as test:
#
# ```bash
# #publicly available docker image "python" on docker hub will be pulled
#
# FROM python:3.10
#
# #creating directory helloworld in container (linux machine)
#
# RUN mkdir c:\home\docker_hw
#
# #copying helloworld.py from local directory to container's helloworld folder
#
# COPY main.py /home/docker_hw/main.py
#
# #running helloworld.py in container
#
# CMD python /home/docker_hw/main.py
# ```
#
# 3. Build file using docker image build -t doc_test .
# Dont forget the dot
#
# 4. access docker shell docker exec -it epic_keldysh bash
#
# 5.
#
# ### Results/Conclusions
#
#
# ### Next Steps

# %% [markdown]
#  # 27th Apr
# ---
# ### Project
# NLP Pipeline
#
# ### AIM
#
#
# ### Description
# 1. Merge fig 4 and 5 and fix fig 6 in paper
#
# 2. Generate craft disease corpora
#
# 3. Run BC5CDR on craft disease
#
#
# ### Results/Conclusions
#
#
# ### Next Steps

# %% [markdown]
#  # 5th May
# ---
# ### Project
# NLP Pipeline
#
# ### AIM
#
#
# ### Description
# 1. Worked with docria implementation, generating a graphical abstract using biorender and figuring out my poster for the last few days
#
# ![Computational%20Biology%20Workflow%20for%20the%20Study%20of%20Protein-Protein%20Complexes%20%281%29.png](attachment:Computational%20Biology%20Workflow%20for%20the%20Study%20of%20Protein-Protein%20Complexes%20%281%29.png)
#
# 2. Today I focused on bug fixes and tests for the pipeline and re parts
#
# 3. NEL needs to work within the pipline. I will run tests the next few days
#
# 4.
#
#
# ### Results/Conclusions
#
#
# ### Next Steps

# %% [markdown]
#  # 10th May (and previous)
# ---
# ### Project
# NLP Pipeline
#
# ### AIM
#
#
# ### Description
# 1. The pipeline had some bugs:
# Jacob
#     Typos
#     In tutorial Jupyter notebook
#     "trianed" instead of trained
#     On
#     "pyhton" instead of python
#     Indenting in config file
#     Installation Error while setting up Conda env
#     ERROR: Encountered corrupt package tarball at /home/x_jackr/.conda/pkgs/qtwebkit-5.212-h4eab89a_4.conda. Conda has left it in place.  Please report this to the maintainers of your package.       For the defaults channel, please report to https://github.com/continuumio/anaconda-issues
#     Add name specifier option for "conda create command"
#     Missing packages
#
#     Traceback (most recent call last):
#
#      File "/proj/berzelius-2021-21/users/jacob/EasyNER/main.py", line 18, in <module>
#
#        from scripts import metrics
#
#      File "/proj/berzelius-2021-21/users/jacob/EasyNER/scripts/metrics.py", line 4, in <module>
#
#        import conlleval
#
#     ModuleNotFoundError: No module named 'conlleval'
#
#     Runtime issues
#     'metrics' keyword missing in config
#     "add_tags" keyword missing in config
#     "entities" keyword missing
#
#     Traceback (most recent call last):
#
#      File "/proj/berzelius-2021-21/users/jacob/EasyNER/main.py", line 313, in <module>
#
#       run_analysis(config["analysis"], ignore=ignore["analysis"])
#
#      File "/proj/berzelius-2021-21/users/jacob/EasyNER/main.py", line 234, in run_analysis
#
#       analysis.run(analysis_config)
#
#      File "/proj/berzelius-2021-21/users/jacob/EasyNER/scripts/analysis.py", line 106, in run
#
#        df = run_analysis(input_files_list)
#
#      File "/proj/berzelius-2021-21/users/jacob/EasyNER/scripts/analysis.py", line 45, in run_analysis
#
#        if len(sent["entities"])!=0:
#
#     KeyError: 'entities'
#
#     Models
#     Models folder appears to be empty? Is this correct?
#
# sonja
# issues with splitter, filepath and analysis scripts
#     entity = analysis_config["input_path"].split("_")[-1].strip("\/\n ")
#
#     prefix = analysis_config["input_path"].split("_")[-2].strip("\/\n ")
#
#
# Me
#
# 1. Text loader bugfix - multiple entries
# 2. Analysis fix - prefix and entities
# 3. Config fix - filepaths
# 4. Main fix - conlleval etc extra packages removal
# 5.
#
#
#
# ### Results/Conclusions
#
#
# ### Next Steps

# %% [markdown]
#  # 29th May (and previous)
# ---
#
# ### Previously
#
# The last 2 weeks were spent on creating the poster, applying for the LU travel grant, getting poster printed, attending LU symposium, Jacob and Klara's defense. Meanwhile I have worked on the error file for the models.
# ### Project
# NLP Pipeline
#
# ### AIM
#
#
# ### Description
# starting off with pubmed, bulk download is possible but the system hangs pretty quickly. Need to find an alternate solution
#
#
#
#
# ### Results/Conclusions
#
#
# ### Next Steps

# %% [markdown]
#  # 2nd June
# ---
#
# ### Project
# NLP Pipeline
#
# ### AIM
# Run chem models on entire pubmed annual baseline
#
# ### Description
# Checked the gz files on baseline. 1166 files for 2023 baseline. Parsed the first file using the pubmed parser.
#
# here is the link to the zip archive: https://lhncbc.nlm.nih.gov/ii/information/MBR/Baselines/2023.html
#
# the files are in FML, couldn't load them
#
# heres a new github repo: github.com/rafsanahmed/pubmed_loader
#
#
#
#
#
# ### Results/Conclusions
#
#
# ### Next Steps

# %% [markdown]
#  # 7th June
# ---
#
# ### Project
# NLP Pipeline
#
# ### AIM
# Fix pubmed loader
#
# ### Description
# Over the last couple workdays I have fixed the pubmed loader script and now it is a smooth download. The 2023 annual baseline, which is papers untill 2022 end, contains 1166 xml files. I have parsed them to JSON that can be fed to the pipeline.
#
# I have also checked the daily update file (7th June 2023), and found 204 additional files, making the total 1370 files as of today. I have also counted the available abstracts within the files. each of these files contain 30000 articles, but not all of them contain abstracts. from the baseline I got 23897962 articles with abstracts.
#
# The update files are running now
#
# The splitter code we have currently won't work with bulk pubmed data. In that case, I am aiming to create a pre-batched command to be added to the splitter file.
#
# once we have that, then the idea is to just pass the files to the model
#
#
#
#
# ### Results/Conclusions
#
#
# ### Next Steps

# %% [markdown]
#  # 5th July
# ---
#
# ### Project
# NLP Pipeline
#
# ### AIM
#
#
# ### Description
#
# Got pubmed working and been processing 1166 files + 204 additional files.
# 1166 files contains 23897962 abstracts
# 200 additional files contain 3119375 abstracts
#
# total 27017337 abstracts
#
#
# 100 files have been split + chem-dis-gene models run
#
# each take around 3 days. Trying to run 16 files at a time with multiple jobs. Trying to make the process more efficient.
#
# ### Results/Conclusions
#
#
# ### Next Steps

# %% [markdown]
#  # 2nd August
# ---
#
# ### Project
# WSL + docker
#
# ### AIM
#
#
# ### Description
#
# 1. Installing wsl is as simple as wsl --install
#
# 2. to limit memory use editor "$(wslpath "C:\Users\YourUsername\.wslconfig")"
#
#     and then:
#     [wsl2]
#     memory=3GB
#
#     to limit RAM to 3GB
#
#     ref: https://www.aleksandrhovhannisyan.com/blog/limiting-memory-usage-in-wsl-2/
#
# 3. https://stackoverflow.com/questions/74236087/set-max-disk-usage-for-docker-using-wsl2
#
#
#
# ### Results/Conclusions
#
#
# ### Next Steps

# %% [markdown]
#  # 3rd August
# ---
#
# ### Project
# NLP EasyNER
#
# ### AIM
# Faster processing
#
# ### Description
#
# Turns out converting the json file to a HF dataset and applying mapping to the sentences greatly reduces the runtime. NER_biobert.py script need a severe update
#
# Updating atm on vscode
#
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
#
# Normalization is a key step in NER post processing. I need to check out scispacy normalization for easyner

# %% [markdown]
#  # 4th August
# ---
#
# ### Project
# NLP EasyNER
#
# ### AIM
# Faster processing
#
# ### Description
#
# ###### meeting with embl/ europepmc
# interested
#
# <ins>They have</ins>:
#
# 45m abstracts = 8m fulltext + pretrained models + metagenomic analysis of 16 entities
# hybrid models
# curators in the loop - generating future problem annotations (?)
#
# some models (baseline) from 10 papers atm
#
# 42k preprints full text
# supplementary files and containing information into a graph
#
#
# Normalization increases 20% accuracy with DL models
# bioformer8L for fastaf inference
#
#
# Interested in RE-> |KG|
#
# <ins>They can</ins>:
#
# 1. Help with data
# 2. Ideas on training
# 3. Maybe resources -> I should use my own
#
# <ins>What they get from us</ins>:
#
# Annotated data using models
#
# ##### Rest
#
# Updating vscode and pushing to github + berzelius
#
# reduced the runtime a few folds using gpu inference and mapping. However, it feels still not enough. Now pubmed can be processed in 2 days ish
#
#
#
#
# ### Results/Conclusions
#
#
# ### Next Steps
#
# Normalization is a key step in NER post processing. I need to check out scispacy normalization for easyner

# %% [markdown]
# # Log interruption
#
# Due to not having a laptop, I wasn't able to keep detailed logs. But here is what happened:
#
# 1.

# %% [markdown]
#  # 7th August
# ---
#
# ### Project
# NLP EasyNER
#
# ### AIM
# Summary for Sonja
#
# ### Description
#
# 1. Downloaded and processed the pubmed abstracts collection.
# 2. Fix EasyNER script for faster inference on pubmed. From 16 article files (each contains max 30k article abstracts) in 3 days to 100 article files in 2 days.
# 2. Ran disease, gene and chemical models on pubmed
# 3. Explored relation extraction models for EasyNER + RE manuscript
# 4. Attended conference in Lyon
# 5. Halric project + EUROPE PMC
# 6. SAM cytosol
# 7.
#
# ### Results/Conclusions
#
#
# ### Next Steps
#
# Normalization is a key step in NER post processing. I need to check out scispacy normalization for easyner

# %% [markdown]
#  # 28th November
# ---
#
# ### Project
# NLP EasyNER
#
# ### AIM
# Summary for Sonja
#
# ### Description
#
# 1. Downloaded and processed the pubmed abstracts collection.
# 2. Fix EasyNER script for faster inference on pubmed. From 16 article files (each contains max 30k article abstracts) in 3 days to 100 article files in 2 days.
# 2. Ran disease, gene and chemical models on pubmed
# 3. Explored relation extraction models for EasyNER + RE manuscript
# 4. Attended conference in Lyon
# 5. Halric project + EUROPE PMC
# 6. SAM cytosol
# 7.
#
# ### Results/Conclusions
#
#
# ### Next Steps
#
# Normalization is a key step in NER post processing. I need to check out scispacy normalization for easyner

# %% [markdown]
#  # 18 Apr 2024 Recap
# ---
#
# ### EasyNER
# the paper is submitted
# https://github.com/Aitslab/EasyNER
#
# Codeocean: https://doi.org/10.24433/CO.6908880.v1
#
# arxiv: https://arxiv.org/abs/2304.07805 (v2)
#
# Awaiting review from gigascience.
#
# A lot of changes had been made on the paper. But mainly on the figures and the filesystems. Cell model chooses not to function still. For that the entire dataset structure needs to be changed. But for that I will need quite a bit of time. Code capsule seems to function well
#
# ### Knowledge graph
#
# The cell death knowledge graph is well underway. I am writing the script as well as prepping the code. For now:
#
# 1. Cell death, cell death process, disease, chemical, gene, species models are present. I have merged the files and taken all of them into consideration for analysis. However a memory issue arises.
#
# 2. 1366 files from annual baseline 2023. I did not use the update files at this stage, since the 2024 baseline was different in terms of files. SO I will have to run the whole thing again
#
# following are the next steps:
#
# 1. Run cd and cdp v2 dictionaries that sonja shared.
# 2. Merge and prune
# 3. Run analysis\
# 4. package the code properly
# 5. I guess add everything to easyNLP
#
# ### RAG-Norm
#
# Initial results looked promising. I aimed to do a global pooling and try normalizing in that way. However, i got mixed results. I will finish the paper by May (realistically). The new RAG research helps a lot. This can be integrated to the easynlp pipeline
#
# ### PhD
# Extension needed
# RE side
#
# ### Additional
#
# tokyo check
# 3 day event in may
# powwow
# jobhunt
# distributed ML + cloud
# several courses

# %% [markdown]
#  # 18 Apr 2024
# ---
#
# ### Project
# EasyNLP ++ celldeath graph
#
# ### Aim
# Finalize first draft today
# run v2 files on cd and cdp
# merge by tonight
#
# ### Description
# SOnja sent me new v2 files. They need to be run
# I am writing in the meanting
#
# ### Results/conclusions
#
# ### Next steps
# tomorrow taking a holiday

# %% [markdown]
# # 22 Apr 2024
# ---
#
# ### Project
# EasyNLP ++ celldeath graph
#
# ### Aim
# cont...
#
# ### Description
# V2 cell death files running well. CDP files are run now
#
# ### Results/conclusions
# analysis done, v2 merger remaining then proper pruning needs to be done
#
# ### Next steps
# 1. Writing\
# 2. Pruning scripts
# 3. Scripts to generate graph
# 4. Graph algo, cypjher and neo4j

# %% [markdown]
# # 25 AUG 2024
# ---
#
# ### Project
# EasyNER review
#
# ### Aim
# review
#
# ### Description
# Files updated, review nearly finished.
#
# 1. HunFLAIR files obtained on Nov 4, 2021
# 2. HUNFLAIR 2 files obtained on June 24,2024
# 3. CRAFT obtained on March 24, 2023
# 4. Biored obtained 15th July 2024 from
#
# ### Results/conclusions
#
#
#
# ### Next steps
# 1.

# %% [markdown]
# # 6 SEPT 2024
# ---
#
# ### Project
# EasyNLP ++ celldeath graph
#
# ### Aim
# Sonjas questions + tasks
#
# ### Description
# 1. Is title involved in the easyner runs?
# Ans. When preprocessing BioID, medmentions, tmvar3 AND Biored, I have included the title in the processed files.
# BioID does not have a title and the assumed title (with t tag) is the abstract.
# Medmentions corpus has titles and they were incorporated with the abstract.
# TMVAR already has title and abstract in the text. So does biored
#
# 2. Sonja sent me the preprocessed files on sept 6. They include medmention original, bioid preprocessed and tmvar3 preprocessed. I have downloaded them into sonja_preprocessed folder on TUF
#
# Medmention [cell, chemical, disease, gene, species]
# TMVAR v3 [gene, species, cell]
# BioID [gene, chemical, species, cell] doesnt get more classes but more annotations after preprocessing
#
# 2.1 I convert the medmention orig file into json and run easyner
#
# ### Results/conclusions
# Evan French | An overview of biomedical entity linking 2023
#
# ### Next steps
# 1.

# %% [markdown]
# # 10 SEPT 2024
# ---
#
# ### Project
# EASYNER
#
# ### Aim
# Sonjas questions + tasks
#
# ### Description
# I have processed the annotated dataset to raw dataset.
# Medmentions 2 run on hf2 is 693.73 s
#
#
#
# ### Results/conclusions
# Evan French | An overview of biomedical entity linking 2023
#
# ### Next steps

# %% [markdown]
# # 11 SEPT 2024
# ---
#
# ### Project
# EASYNER
#
# ### Aim
# Sonjas questions + tasks
#
# ### Description
# Compared rerun hf2 and existing. There are differences
#
# Follwing tasks for today:
#
# 1. Merge easyner for medmentions
# 2. Convert pubtator for medmentions
# 3. Run evaluations
#
# ### Results/conclusions
# Evan French | An overview of biomedical entity linking 2023
#
# ### Next steps

# %% [markdown]
# # 12 SEPT 2024
# ---
#
# ### Project
# EASYNER
#
# ### Aim
# Sonjas questions + tasks
#
# ### Description
# Compared rerun hf2 and existing. There are differences
#
# Follwing was step by step for postprocessing:
#
# 1. Run easyner on corpus (medmentions-orig) and get annotations.
# 2. Run separator merge script on results
# 3. Run convert to pubtator script
# 4. Evaluate
#
#
# ### Results/conclusions
# Evan French | An overview of biomedical entity linking 2023
#
# ### Next steps

# %% [markdown]
# # 13 SEPT 2024
# ---
#
# ### Project
# EASYNER
#
# ### Aim
# Sonjas questions + tasks
#
# ### Description
# Got timekeep done
#
#
# ### Results/conclusions
# Evan French | An overview of biomedical entity linking 2023
#
# ### Next steps

# %% [markdown]
# # 27 SEPT 2024
# ---
#
# ### Project
# EASYNER
#
# ### Aim
# Sonjas questions + tasks
#
# ### Description
#
# Biored is not available for several models like bern, bent, pubtator and scispacy. Those values are expected to be zero. I checked the HF2 paper and saw that it was trained on biored corpus.
#
# 1. Celline:
#
# Biored is not available for several models like bern, bent, pubtator and scispacy. Those values are expected to be zero. For old goldstandard medmentions (from hf2 repo), there were no celline annotation. Therefore, the hits are zero.BERN seems to have high precision but very low recall. Scispacy does not have cell values, therefore
#
# 2. Chemical:
# Noticeable differences between goldstandard and old goldstandard. Tmvar3 not in the corpus list. HF2 does really well with biored. Which makes me question if it is one of the training corpora. Turns out it is true.
#
# 3. Disease:
# HF2 peforms well with medmentions again and has slight differences from the original annotations in the HF2 repo. HF2 also performs well on biored (because it is trained on biored). EasyNER has a 0.82 f1 score on biored which may show significance
#
# 4. Gene:
# Medmentions old goldstandard file doesnt contain genes but new one does. Therefore the f1 score is zero. EasyNER seems to perform well with genes. The hunflair and hunflair2 runs seems to have slight differences. Pubtator value is quite high for tmvar_v3
#
# 5. Species:
# BENT and pubtator seem to do really well with species. EasyNER does a good job only in the case of biored.
#
#
# ### Results/conclusions
# Evan French | An overview of biomedical entity linking 2023
#
# ### Next steps
